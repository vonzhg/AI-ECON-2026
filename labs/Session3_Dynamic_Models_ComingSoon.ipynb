# %% [markdown]
# # Session 3 Lab — Deep Learning for Dynamic Models
#
# > ⏳ **Coming soon.** This lab notebook will be released for **Session 3** of *AI for Economic Research (2026)*.
#
# **Planned content:** Classical VFI benchmark and neural-network solutions (Euler-equation solver, deep VFI).
#
# ---
#
# Run the released notebooks in the cloud with **GitHub Codespaces** — see the [Labs page](index.html) for the one-click button. No local setup required.

# %%
print("Session 3 lab — coming soon. Check the course site / WeChat group for updates.")

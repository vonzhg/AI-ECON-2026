# %% [markdown]
# # Session 2 Lab — Machine Learning Basics
#
# > ⏳ **Coming soon.** This lab notebook will be released for **Session 2** of *AI for Economic Research (2026)*.
#
# **Planned content:** Neural networks as non-parametric regression; yield-curve prediction with real FRED data.
#
# ---
#
# Run the released notebooks in the cloud with **GitHub Codespaces** — see the [Labs page](index.html) for the one-click button. No local setup required.

# %%
print("Session 2 lab — coming soon. Check the course site / WeChat group for updates.")

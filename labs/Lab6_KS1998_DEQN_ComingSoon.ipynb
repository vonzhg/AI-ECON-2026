# %% [markdown]
# # Session 4 Lab — Krusell–Smith (1998) with Deep Equilibrium Nets
#
# > ⏳ **Coming soon.** This lab notebook will be released for **Session 4** of *AI for Economic Research (2026)*.
#
# **Planned content:** Solve KS1998 in PyTorch: calibration, simulation, and Euler-equation accuracy validation.
#
# ---
#
# Run the released notebooks in the cloud with **GitHub Codespaces** — see the [Labs page](index.html) for the one-click button. No local setup required.

# %%
print("Session 4 lab — coming soon. Check the course site / WeChat group for updates.")

# %% [markdown]
# # Session 5 Lab — LLMs & Text as Economic Data
#
# > ⏳ **Coming soon.** This lab notebook will be released for **Session 5** of *AI for Economic Research (2026)*.
#
# **Planned content:** Tokenization and embedding arithmetic; FOMC minutes with LLM embeddings vs. TF-IDF.
#
# ---
#
# Run the released notebooks in the cloud with **GitHub Codespaces** — see the [Labs page](index.html) for the one-click button. No local setup required.

# %%
print("Session 5 lab — coming soon. Check the course site / WeChat group for updates.")

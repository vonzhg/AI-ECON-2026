# %% [markdown]
# # Session 6 Lab — Agentic AI Case-Study Replication
#
# > ⏳ **Coming soon.** This lab notebook will be released for **Session 6** of *AI for Economic Research (2026)*.
#
# **Planned content:** Guided replication of a case study end-to-end using an agentic coding assistant.
#
# ---
#
# Run the released notebooks in the cloud with **GitHub Codespaces** — see the [Labs page](index.html) for the one-click button. No local setup required.

# %%
print("Session 6 lab — coming soon. Check the course site / WeChat group for updates.")
